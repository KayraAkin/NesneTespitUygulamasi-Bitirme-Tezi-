# %%
import matplotlib.pyplot as plt
from matplotlib import image
import numpy as np
from skimage import data , color
from skimage.transform import rescale , resize , downscale_local_mean
classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]
i1 = image.imread('C:/Users/Kayra/OneDrive/Masaüstü/nesne tespit resim/kopekler.jpg')
newi1 = resize(i1,(32,32,3),)

model = tf.keras.models.load_model("C:/Users/Kayra/OneDrive/Masaüstü/Nesne Tespit Modeller/InceptionV3Yeni.h5")
im = np.expand_dims(newi1 , axis = 0)
plt.imshow(i1)
keypoints = model.predict(im)
print(classes[np.argmax(keypoints)])
print(classes[np.argmax])
# Out:
# 1/1 [==============================] - 1s 1s/step
# dog
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20216\1904199351.py in <module>
#      13 keypoints = model.predict(im)
#      14 print(classes[np.argmax(keypoints)])
# ---> 15 print(classes[np.argmax])
#
# TypeError: list indices must be integers or slices, not function
